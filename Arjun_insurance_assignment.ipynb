# %%
import pandas as pd

# %%
data = pd.read_csv('/content/insurance.csv')

# %%
1. Count for each categories of ‘region

# %%
region_counts = data['region'].value_counts()
print(region_counts)
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
2. Find 50 records of highest ‘age’ and export data/table to desktop

# %%
import os

# %%
home_dir = os.path.expanduser("~")

# %%
desktop_path = os.path.join(home_dir, "Desktop")

# %%
if not os.path.exists(desktop_path):
    os.makedirs(desktop_path)

# %%
file_path = os.path.join(desktop_path, "top_50_ages.csv")
top_50_ages.to_csv(file_path, index=False)

# %%
3. Add index name ‘quick’ on ‘id’

# %%
data.set_index('id', inplace=True)
data.index.name = 'quick'

# %%
4. Describe the schema of table

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1338 entries, 1001 to 2338
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB
# None

# %%
5. Create view name as ‘gender’ where users can not see ‘sex’ [Hint: first run
appropriate query then create view]

# %%
gender_view = data.drop(columns=['sex'])

# %%
6. Rename the view as ‘type’

# %%
type_view = gender_view

# %%
7. Count how many are ‘northwest’ insurance holders

# %%
northwest_count = (data['region'] == 'northwest').sum()
print(f"Number of 'northwest' insurance holders: {northwest_count}")
# Out:
# Number of 'northwest' insurance holders: 325

# %%
8. Count how many insurance holders were ‘femail’

# %%
female_count = (data['sex'] == 'female').sum()
print(f"Number of female insurance holders: {female_count}")
# Out:
# Number of female insurance holders: 662

# %%
9. Create Primary key on a suitable column

# %%
data.index.is_unique
# Out:
# True

# %%
10. Create a new column ‘ratio’ which is age multiply by bmi

# %%
data['ratio'] = data['age'] * data['bmi']

# %%
11. Arrange the table from high to low according to charges

# %%
sorted_by_charges = data.sort_values(by='charges', ascending=False)
print(sorted_by_charges.head())
# Out:
#        age     sex     bmi  children smoker     region      charges     ratio
# quick
# 1544    54  female  47.410         0    yes  southeast  63770.42801  2560.140
# 2301    45    male  30.360         0    yes  southeast  62592.87309  1366.200
# 2231    52    male  34.485         3    yes  northwest  60021.39897  1793.220
# 1578    31  female  38.095         1    yes  northeast  58571.07448  1180.945
# 1820    33  female  35.530         0    yes  northwest  55135.40209  1172.490

# %%
12. Find MAX of ‘charges’

# %%
max_charges = data['charges'].max()
print(f"The maximum charges are: {max_charges}")
# Out:
# The maximum charges are: 63770.42801

# %%
13. Find MIN of ‘charges’

# %%
min_charges = data['charges'].min()
print(f"The minimum charges are: {min_charges}")
# Out:
# The minimum charges are: 1121.8739

# %%
14. Find average of ‘charges’ of male and female

# %%
average_charges = data.groupby('sex')['charges'].mean()
print(average_charges)
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
15. Write a Query to rename column name sex to Gender

# %%
data.rename(columns={'sex': 'Gender'}, inplace=True)

# %%
16. Add new column as HL_Charges where more than average charges should be categorized as HIGH and less than average charges should be categorized as LOW

# %%
average_charges = data['charges'].mean()
data['HL_Charges'] = data['charges'].apply(lambda x: 'HIGH' if x > average_charges else 'LOW')

# %%
17. Change location/position of ‘smoker’ and bring before ‘children’

# %%
cols = list(data.columns)
smoker_index = cols.index('smoker')
children_index = cols.index('children')
cols.insert(children_index, cols.pop(smoker_index))

# %%
data = data[cols]

# %%
18. Show top 20 records

# %%
print(data.head(20))
# Out:
#        age  Gender     bmi smoker  children     region      charges     ratio  \
# quick
# 1001    19  female  27.900    yes         0  southwest  16884.92400   530.100
# 1002    18    male  33.770     no         1  southeast   1725.55230   607.860
# 1003    28    male  33.000     no         3  southeast   4449.46200   924.000
# 1004    33    male  22.705     no         0  northwest  21984.47061   749.265
# 1005    32    male  28.880     no         0  northwest   3866.85520   924.160
# 1006    31  female  25.740     no         0  southeast   3756.62160   797.940
# 1007    46  female  33.440     no         1  southeast   8240.58960  1538.240
# 1008    37  female  27.740     no         3  northwest   7281.50560  1026.380
# 1009    37    male  29.830     no         2  northeast   6406.41070  1103.710
# 1010    60  female  25.840     no         0  northwest  28923.13692  1550.400
# 1011    25    male  26.220     no         0  northeast   2721.32080   655.500
# ...

# %%
19. Show bottom 20 records

# %%
print(data.tail(20))
# Out:
#        age  Gender     bmi smoker  children     region      charges     ratio  \
# quick
# 2319    35    male  39.710     no         4  northeast  19496.71917  1389.850
# 2320    39  female  26.315     no         2  northwest   7201.70085  1026.285
# 2321    31    male  31.065     no         3  northwest   5425.02335   963.015
# 2322    62    male  26.695    yes         0  northeast  28101.33305  1655.090
# 2323    62    male  38.830     no         0  southeast  12981.34570  2407.460
# 2324    42  female  40.370    yes         2  southeast  43896.37630  1695.540
# 2325    31    male  25.935     no         1  northwest   4239.89265   803.985
# 2326    61    male  33.535     no         0  northeast  13143.33665  2045.635
# 2327    42  female  32.870     no         0  northeast   7050.02130  1380.540
# 2328    51    male  30.030     no         1  southeast   9377.90470  1531.530
# 2329    23  female  24.225     no         2  northeast  22395.74424   557.175
# ...

# %%
20. Randomly select 20% of records and export to desktop

# %%
sample_20_percent = data.sample(frac=0.2)
file_path = os.path.join(desktop_path, "sample_20_percent.csv")
sample_20_percent.to_csv(file_path, index=False)

# %%
21. Remove column ‘ratio’

# %%
data.drop(columns=['ratio'], inplace=True)
# Out:
# <ipython-input-45-0ba085871f84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['ratio'], inplace=True)

# %%
22. Craete one example of Sub Queries involving ‘bmi’ and ‘sex’ and give explanation in the script itself with remarks by using #

# %%
average_bmi = data['bmi'].mean()
high_bmi_females_avg = data[(data['Gender'] == 'female') & (data['bmi'] > average_bmi)]['bmi'].mean()
print(f"Average BMI of high BMI females: {high_bmi_females_avg}")
# Out:
# Average BMI of high BMI females: 35.65857843137255

# %%
23. Create a view called Female_HL_Charges that shows only those data where
HL_Charges is High, Female, Smokers and with 0 children

# %%
female_hl_charges_view = data[(data['HL_Charges'] == 'HIGH') & (data['Gender'] == 'female') & (data['smoker'] == 'yes') & (data['children'] == 0)]

# %%
24. Update children column if there is 0 children then make it as Zero Children, if 1 then one_children, if 2 then two_children, if 3 then three_children, if 4 then
four_children if 5 then five_children else print it as More_than_five_children.

# %%
data['children'] = data['children'].replace({0: 'Zero Children', 1: 'One Child', 2: 'Two Children', 3: 'Three Children', 4: 'Four Children', 5: 'Five Children'})
data.loc[data['children'].isin(['6', '7', '8', '9']), 'children'] = 'More_than_five_children'
# Out:
# <ipython-input-49-a7c848c89316>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['children'] = data['children'].replace({0: 'Zero Children', 1: 'One Child', 2: 'Two Children', 3: 'Three Children', 4: 'Four Children', 5: 'Five Children'})
